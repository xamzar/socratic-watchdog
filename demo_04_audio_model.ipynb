# %% [markdown]
# # 🧠 Chapter 4 — Audio + Model
#
# Toggle TTS, switch LLM providers from a numbered list.

# %%
# %unload_ext socratic_watchdog
# %load_ext socratic_watchdog
# %socratic_debug on
# %socratic_audio off
# Out:
# 🧠  Socratic Watchdog unloaded.
# 🧠  Socratic Watchdog loaded!
# ──────────────────────────────
# ⚠️   %%socratic MUST be the first line of a cell!
# ──────────────────────────────
# •  %%socratic          — run a cell with analysis
# •  %socratic_generate_tests   — auto-gen hidden tests from task
# •  %socratic_watch    — watch every cell
# •  %socratic_audio    — toggle TTS audio on/off
# •  %socratic_model    — choose LLM model
# •  %socratic_debug    — toggle debug trace (timing, LLM, TTS)
# •  %socratic_auto_tests — auto-generate tests on every %socratic_task
# •  %socratic_explore — toggle exploration mode (free experimentation)
# •  %socratic_clear_cache — clear generated-tests cache (demos)
#
# Try:  %socratic_help
#
# 🐛  Debug ON
# 🔇  Audio OFF

# %% [markdown]
# ### Task — Write a function add(a, b) that returns a + b

# %% [markdown]
# ## Audio — off = no sound, boxes still appear

# %%
# %socratic_audio off
# Out:
# 🔇  Audio OFF

# %%
# %%socratic
# def add(a, b):
#     return a - b
# Out:
# 🤖  LLM: deepseek-chat  →  1.292s
# <div style='background:#fef3c7; border-left:4px solid #f59e0b;padding:12px 16px; margin:8px 0; border-radius:4px;font-size:15px; line-height:1.5;'><strong>🏛️  Socrates asks:</strong><br>My friend, I see you have written a function called `add`, yet within it you perform a subtraction. What do you suppose might be the difference between the name of your function and the operation it carries out?</div>
# ┌─ Socratic Debug ───────────────────────────────────┐
# │ cell execution                             0.0010s │
# │ LLM analysis                               1.2920s │
# │ TTS                                0.0030s  espeak │
# ├────────────────────────────────────────────────────┤
# │ TOTAL                                    1.3200s  │
# └────────────────────────────────────────────────────┘

# %%
# %socratic_audio on

# %% [markdown]
# ## Model — numbered picker, base URLs automatic

# %%
# %socratic_model

# %%
# %socratic_model 4   # GPT-4o Mini
# %socratic_model gpt  # fuzzy match
# %socratic_model 1      # back to DeepSeek Chat
