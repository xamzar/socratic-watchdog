# %% [markdown]
# # 🧠 Chapter 3 — Auto-Watch
#
# Every cell analyzed automatically — no `%%socratic` needed.  3s debounce.

# %%
# %unload_ext socratic_watchdog
# %load_ext socratic_watchdog
# %socratic_debug on
# %socratic_audio off

# %% [markdown]
# ### Task — Write a function greet(name) that returns 'Hello, ' + name

# %%
# %socratic_watch on

# %%
def greet(name):
    return "Hello, " + name

# %%
def greet(name):
    return "Hello, " name

# %%
greet(42)

# %%
# %socratic_watch off
