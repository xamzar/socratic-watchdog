# %% [markdown]
# # 🧠 Socratic Watchdog — Demo
#
# | # | Notebook |
# |---|---|
# | 1 | `demo_01_basics.ipynb` — praise, questions, errors |
# | 2 | `demo_02_tests.ipynb` — manual + auto-generated tests |
# | 3 | `demo_03_watch.ipynb` — auto-watch mode |
# | 4 | `demo_04_audio_model.ipynb` — audio toggle + model picker |
#
# 📚 `lesson_dictionaries.ipynb` — sample lesson (dictionaries)
